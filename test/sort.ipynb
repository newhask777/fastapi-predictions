# %%
import pandas as pd
import requests

# %%
response = requests.get('http://127.0.0.1:8000/home/api').json()

# %%
response = response['games']

df = pd.DataFrame(response)

# %%
df.to_csv('games.csv')

# %%
df = pd.read_csv('games.csv')

# %%
df
# Out:
#      Unnamed: 0                              tournament_slug  \
# 0             0                   uefa-nations-league-finals
# 1             1                   uefa-nations-league-finals
# 2             2  european-championship-qualification-group-b
# 3             3  european-championship-qualification-group-b
# 4             4  european-championship-qualification-group-c
# ..          ...                                          ...
# 109         109           international-friendly-games-women
# 110         110                           u21-friendly-games
# 111         111                           u21-friendly-games
# 112         112       tournoi-maurice-revello-knockout-stage
# 113         113       tournoi-maurice-revello-knockout-stage
#
#      tournament_players_stat  home_team_type away_team_shortname  \
# 0                       True               0               Italy
# 1                       True               0               Spain
# ...
